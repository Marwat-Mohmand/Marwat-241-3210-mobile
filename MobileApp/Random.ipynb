// %%
Random rnd = new();

// %%
Console.WriteLine(rnd.Next(10));
Console.WriteLine(rnd.Next(-10, -5));
Console.WriteLine(rnd.Next());
Console.WriteLine(rnd.NextInt64());
Console.WriteLine(rnd.NextDouble()); // [0.0;1.0)
// Out:
// 4
// -8
// 1346656516
// 2006986253874341925
// 0,8725750780364777

// %%
var numbers = new int[10];

for (int i = 0; i < 10; i++)
    numbers[i] = rnd.Next(100);

numbers
// Out:
// <div class="dni-plaintext"><pre>[ 50, 33, 97, 2, 61, 98, 30, 62, 94, 41 ]</pre></div><style>
// .dni-code-hint {
//     font-style: italic;
//     overflow: hidden;
//     white-space: nowrap;
// }
// .dni-treeview {
//     white-space: nowrap;
// }
// .dni-treeview td {
//     vertical-align: top;
//     text-align: start;
// }
// details.dni-treeview {
//     padding-left: 1em;
// }
// table td {
//     text-align: start;
// }
// table tr {
//     vertical-align: top;
//     margin: 0em 0px;
// }
// table tr td pre
// {
//     vertical-align: top !important;
//     margin: 0em 0px !important;
// }
// table th {
//     text-align: start;
// }
// </style>

// %%
Random rndFix = new(100);

var numbers = new int[10];

for (int i = 0; i < 10; i++)
    numbers[i] = rndFix.Next(100);

numbers
// Out:
// <div class="dni-plaintext"><pre>[ 96, 15, 66, 90, 35, 94, 71, 61, 34, 14 ]</pre></div><style>
// .dni-code-hint {
//     font-style: italic;
//     overflow: hidden;
//     white-space: nowrap;
// }
// .dni-treeview {
//     white-space: nowrap;
// }
// .dni-treeview td {
//     vertical-align: top;
//     text-align: start;
// }
// details.dni-treeview {
//     padding-left: 1em;
// }
// table td {
//     text-align: start;
// }
// table tr {
//     vertical-align: top;
//     margin: 0em 0px;
// }
// table tr td pre
// {
//     vertical-align: top !important;
//     margin: 0em 0px !important;
// }
// table th {
//     text-align: start;
// }
// </style>
