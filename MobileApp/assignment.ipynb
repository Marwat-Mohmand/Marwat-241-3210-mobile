// %%
Console.WriteLine("Hello from my C# notebook!");

// %%
string name = "Marwat";
int age = 20;

Console.WriteLine($"My name is {name}.");
Console.WriteLine($"My age is {age}.");
// Out:
// My name is Marwat.
// My age is 20.

// %%
int number1 = 10;
int number2 = 20;

int result = number1 + number2;

Console.WriteLine($"{number1} + {number2} = {result}");
// Out:
// 10 + 20 = 30

// %%
Console.WriteLine(255);
Console.WriteLine($"{255:B}");
Console.WriteLine(255.ToString("B"));
Console.WriteLine(0b111111111);
Console.WriteLine(0b_1111_1111);
Console.WriteLine(0x_ff);
Console.WriteLine(0x_f);
// Out:
// 255
// 11111111
// 11111111
// 511
// 255
// 255
// 15

// %%
byte x = 3;
byte y = 5;

Console.WriteLine($"{x:B4} = x");
Console.WriteLine($"{y:B4} = y");
Console.WriteLine();

Console.WriteLine($"{x & y:B4} - AND");
Console.WriteLine($"{x | y:B4} - OR");
Console.WriteLine($"{x ^ y:B4} - XOR");
Console.WriteLine($"{x << 1:B4} = x << 1");
Console.WriteLine($"{x >> 1:B4} = x >> 1");
// Out:
// 0011 = x
// 0101 = y
//
// 0001 - AND
// 0111 - OR
// 0110 - XOR
// 0110 = x << 1
// 0001 = x >> 1

// %%
var z = 3;

Console.WriteLine($"{z:B32}");
Console.WriteLine($"{~z:B} - NOT");
Console.WriteLine($"{(byte)~z:B} - NOT");
// Out:
// 00000000000000000000000000000011
// 11111111111111111111111111111100 - NOT
// 11111100 - NOT

// %%
bool x = true;
bool y = true;

Console.WriteLine($"{x & y} - AND");
Console.WriteLine($"{x | y} - OR");
Console.WriteLine($"{x ^ y} - XOR");
// Out:
// True - AND
// True - OR
// False - XOR
